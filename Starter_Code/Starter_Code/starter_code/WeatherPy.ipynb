# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# Number of cities in the list: 612
# ['formosa do rio preto', 'upper grand lagoon', 'olonkinbyen', 'isafjordur', "verkhov'ye", 'nemuro', 'timimoun', 'bamboo flat', 'bethel', 'raduzhny', 'ribeira grande', 'port hedland', 'nelson', 'thompson', 'port elizabeth', 'luderitz', 'adamstown', 'weno', 'waitangi', 'carnarvon', 'puerto ayora', 'grytviken', 'port-aux-francais', 'bilibino', 'callao', 'margaret river', 'ushuaia', 'vilyuchinsk', 'tolanaro', 'san luis de la loma', 'enewetak', 'west island', 'udachny', 'naze', 'medicine hat', 'blackmans bay', 'kota bharu', 'turpan', 'rongelap', "bich'vinta", 'kodiak', 'edinburgh of the seven seas', 'broome', 'iqaluit', 'westport', 'haiku-pauwela', 'cam ranh', 'san clemente del tuyu', 'argo', 'albany', 'badger', 'corinto', 'taiohae', 'tateyama', 'saint-joseph', 'shimoda', 'negara', 'lompoc', 'terekli-mekteb', 'punta arenas', 'ilulissat', "port saint john's", 'la passe', 'jamestown', 'al kharijah', 'yellowknife', 'inongo', 'castillos', 'lagoa', 'mikuni', 'chandler', 'wailua homesteads', 'hami', 'vilyuysk', 'iskateley', 'tamanrasset', 'qaqortoq', 'port glaud', 'hawaiian paradise park', 'taulaga', 'susner', 'whitehorse', 'kaspiyskiy', 'tongouson', 'puerto natales', 'phan thiet', 'sawakin', 'balabac', 'tazovsky', "mil'kovo", 'keflavik', 'bredasdorp', 'afaahiti', 'aswan', 'sierpc', 'mbandaka', 'puerto deseado', 'fort st. john', 'narrabri', 'springs', 'ibshaway', 'tiksi', 'flying fish cove', 'lihue', 'laguna', 'tonota', 'reggane', 'colonia', 'campos sales', 'houghton', 'anadyr', 'rehoboth', 'whangarei', 'mata-utu', 'chum phae', 'mpraeso', 'rio bueno', 'namibe', 'howard springs', 'longyearbyen', 'el calafate', 'chonchi', 'trabzon', 'revda', 'puerto san carlos', 'quiberon', 'kaiapoi', 'happy valley-goose bay', "kapa'a", 'okha', 'gadzhiyevo', 'kidal', 'ambon', 'necochea', 'vadso', 'portland', 'college', 'papao', 'shangri-la', 'dalianwan', 'dadukou', 'port macquarie', 'bulungu', 'atafu village', 'hithadhoo', 'kalyandurg', 'kirakira', 'antofagasta', 'wynyard', 'mejit', 'okhotsk', 'kerikeri', 'stutterheim', 'powell river', 'petropavlovsk-kamchatsky', 'selfoss', 'hadibu', 'mount isa', 'ola', 'sandnessjoen', 'kataragama', 'fortuna', 'invercargill', 'constantia', 'salmon arm', 'sitka', 'papatowai', 'puerto leguizamo', 'nizhnyaya tavda', 'zhangzhou', 'anatuya', 'champasak', 'ceeldheer', 'guerrero negro', 'changyon', 'paradip garh', 'taroa', 'kavaratti', 'luena', 'mitsamiouli', 'sao jose da coroa grande', 'georgetown', 'redencao', 'el daein', 'port-vila', 'hermanus', 'mollerussa', 'rio grande', "'ohonua", 'prado', 'katsuren-haebaru', 'midvagur', 'ventura', 'cantaura', 'pangoa', 'vila franca do campo', 'saipan', 'stanley', 'kattivakkam', 'ghadamis', 'murzuq', 'ankazoabo', 'jayapura', 'ancud', 'suva', 'manismata', 'mesudiye', 'sirte', 'awjilah', 'port mathurin', 'merizo village', 'kawthoung', 'dunedin', 'lugovoye', 'luau', 'canutama', 'mili', 'tutoia', 'stony plain', 'naha', 'khash', 'sierra grande', 'fort bragg', 'mount pearl', 'praia da vitoria', 'greymouth', 'fale old settlement', 'dwarka', 'lebu', 'goz beida', 'saint-denis', 'masterton', 'fuvahmulah', 'daru', 'antsiranana', 'kavieng', 'popayan', 'san patricio', 'george town', 'talnakh', 'tura', 'dudinka', 'dakoro', 'waddan', 'tazacorte', 'zaranj', 'mendi', 'nadym', 'bel ombre', 'zhangjiajie', 'sisimiut', 'port lincoln', 'tuy hoa', 'paka', 'langzhong', 'boguchar', 'cooma', 'taoudenni', 'akrehamn', 'gorom-gorom', 'valle de la pascua', 'cole harbour', 'pertek', 'revelstoke', 'guane', 'ahau', 'codrington', 'batang', 'korsun-shevchenkivskyi', 'caico', 'hamilton', 'elko', 'xanthi', 'san nicolas', 'mugia', 'miracema do tocantins', 'waingapu', 'ceerigaabo', 'toga village', 'luanda', 'sarina', 'tozeur', 'avarua', 'manohar thana', 'emerald', 'new norfolk', 'nadi', 'alice springs', 'mbanza kongo', 'mandiana', 'mana', "och'amch'ire", 'arraial do cabo', 'victoria', 'prince rupert', 'dakhla', 'east london', 'kununurra', 'tralee', 'bonthe', 'ust-nera', 'malone', "st. john's", 'pemangkat', 'touros', 'auki', 'cha ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city (Step 1)
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        # city_weather = requests.get(city_url).json
        
        # Step 2:
        response = requests.get(city_url)
        
        # Step 3: 
        status_code = response.status_code
        
        # Step 4: 
        if status_code == 200:
            city_weather = response.json()
        else:
            city_weather = {} # failed request
            
        # Step 5: Extraction
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =  city_weather.get("coord", {}).get("lat")
        city_lng = city_weather.get("coord", {}).get("lon")
        city_max_temp = city_weather.get("main", {}).get("temp_max")
        city_humidity = city_weather.get("main", {}).get("humidity")
        city_clouds = city_weather.get("clouds", {}).get("all")
        city_wind = city_weather.get("wind", {}).get("speed")
        city_country = city_weather.get("sys", {}).get("country")
        city_date = city_weather.get("dt")
        city_pressure = city_weather.get("main", {}).get("pressure") # bonus line
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print("City not found. Skipping...")
        print(e)

    # Sleep
    # time.sleep(1)
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | formosa do rio preto
# Processing Record 2 of Set 1 | upper grand lagoon
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | isafjordur
# Processing Record 5 of Set 1 | verkhov'ye
# Processing Record 6 of Set 1 | nemuro
# Processing Record 7 of Set 1 | timimoun
# Processing Record 8 of Set 1 | bamboo flat
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | raduzhny
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | port hedland
# Processing Record 13 of Set 1 | nelson
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | weno
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | port-aux-francais
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | callao
# Processing Record 26 of Set 1 | margaret river
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | vilyuchinsk
# Processing Record 29 of Set 1 | tolanaro
# Processing Record 30 of Set 1 | san luis de la loma
# Processing Record 31 of Set 1 | enewetak
# Processing Record 32 of Set 1 | west island
# Processing Record 33 of Set 1 | udachny
# Processing Record 34 of Set 1 | naze
# Processing Record 35 of Set 1 | medicine hat
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | kota bharu
# Processing Record 38 of Set 1 | turpan
# Processing Record 39 of Set 1 | rongelap
# Processing Record 40 of Set 1 | bich'vinta
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | broome
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | westport
# Processing Record 46 of Set 1 | haiku-pauwela
# Processing Record 47 of Set 1 | cam ranh
# Processing Record 48 of Set 1 | san clemente del tuyu
# Processing Record 49 of Set 1 | argo
# Processing Record 50 of Set 1 | albany
# Processing Record 0 of Set 2 | badger
# Processing Record 1 of Set 2 | corinto
# Processing Record 2 of Set 2 | taiohae
# Processing Record 3 of Set 2 | tateyama
# Processing Record 4 of Set 2 | saint-joseph
# Processing Record 5 of Set 2 | shimoda
# Processing Record 6 of Set 2 | negara
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | terekli-mekteb
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | port saint john's
# Processing Record 12 of Set 2 | la passe
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | al kharijah
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | inongo
# Processing Record 17 of Set 2 | castillos
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | mikuni
# Processing Record 20 of Set 2 | chandler
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | vilyuysk
# Processing Record 24 of Set 2 | iskateley
# Processing Record 25 of Set 2 | tamanrasset
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | port glaud
# Processing Record 28 of Set 2 | hawaiian paradise park
# Processing Record 29 of Set 2 | taulaga
# Processing Record 30 of Set 2 | susner
# Processing Record 31 of Set 2 | whitehorse
# Processing Record 32 of Set 2 | kaspiyskiy
# Processing Record 33 of Set 2 | tongouson
# Processing Record 34 of Set 2 | puerto natales
# Processing Record 35 of Set 2 | phan thiet
# Processing Record 36 of Set 2 | sawakin
# Processing Record 37 of Set 2 | balabac
# Processing Record 38 of Set 2 | tazovsky
# Processing Record 39 of Set 2 | mil'kovo
# Processing Record 40 of Set 2 | keflavik
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | afaahiti
# Processing Record 43 of Set 2 | aswan
# Processing Record 44 of Set 2 | sierpc
# Processing Record 45 of Set 2 | mbandaka
# Processing Record 46 of Set 2 | puerto deseado
# Processing Record 47 of Set 2 | fort st. john
# Processing Record 48 of Set 2 | narrabri
# Processing Record 49 of Set 2 | springs
# Processing Record 0 of Set 3 | ibshaway
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | flying fish cove
# Processing Record 3 of Set 3 | lihue
# Processing Record 4 of Set 3 | laguna
# Processing Record 5 of Set 3 | tonota
# Processing Record 6 of Set 3 | reggane
# Processing Record 7 of Set 3 | colonia
# Processing Record 8 of Set 3 | campos sales
# Processing Record 9 of Set 3 | houghton
# Processing Record 10 of Set 3 | anadyr
# Processing Record 11 of Set 3 | rehoboth
# Processing Record 12 of Set 3 | whangarei
# Processing Record 13 of Set 3 | mata-utu
# Processing Record 14 of Set 3 | chum phae
# Processing Record 15 of Set 3 | mpraeso
# Processing Record 16 of Set 3 | rio bueno
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | howard springs
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | el calafate
# Processing Record 21 of Set 3 | chonchi
# Processing Record 22 of Set 3 | trabzon
# Processing Record 23 of Set 3 | revda
# Processing Record 24 of Set 3 | puerto san carlos
# Processing Record 25 of Set 3 | quiberon
# Processing Record 26 of Set 3 | kaiapoi
# Processing Record 27 of Set 3 | happy valley-goose bay
# Processing Record 28 of Set 3 | kapa'a
# Processing Record 29 of Set 3 | okha
# Processing Record 30 of Set 3 | gadzhiyevo
# Processing Record 31 of Set 3 | kidal
# Processing Record 32 of Set 3 | ambon
# Processing Record 33 of Set 3 | necochea
# Processing Record 34 of Set 3 | vadso
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | college
# Processing Record 37 of Set 3 | papao
# Processing Record 38 of Set 3 | shangri-la
# Processing Record 39 of Set 3 | dalianwan
# Processing Record 40 of Set 3 | dadukou
# Processing Record 41 of Set 3 | port macquarie
# Processing Record 42 of Set 3 | bulungu
# Processing Record 43 of Set 3 | atafu village
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | kalyandurg
# Processing Record 46 of Set 3 | kirakira
# Processing Record 47 of Set 3 | antofagasta
# Processing Record 48 of Set 3 | wynyard
# Processing Record 49 of Set 3 | mejit
# Processing Record 0 of Set 4 | okhotsk
# Processing Record 1 of Set 4 | kerikeri
# Processing Record 2 of Set 4 | stutterheim
# Processing Record 3 of Set 4 | powell river
# Processing Record 4 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 4 | selfoss
# Processing Record 6 of Set 4 | hadibu
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | ola
# Processing Record 9 of Set 4 | sandnessjoen
# Processing Record 10 of Set 4 | kataragama
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | invercargill
# Processing Record 13 of Set 4 | constantia
# Processing Record 14 of Set 4 | salmon arm
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | papatowai
# Processing Record 17 of Set 4 | puerto leguizamo
# Processing Record 18 of Set 4 | nizhnyaya tavda
# Processing Record 19 of Set 4 | zhangzhou
# Processing Record 20 of Set 4 | anatuya
# Processing Record 21 of Set 4 | champasak
# Processing Record 22 of Set 4 | ceeldheer
# Processing Record 23 of Set 4 | guerrero negro
# Processing Record 24 of Set 4 | changyon
# Processing Record 25 of Set 4 | paradip garh
# Processing Record 26 of Set 4 | taroa
# Processing Record 27 of Set 4 | kavaratti
# Processing Record 28 of Set 4 | luena
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | sao jose da coroa grande
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | redencao
# Processing Record 33 of Set 4 | el daein
# Processing Record 34 of Set 4 | port-vila
# Processing Record 35 of Set 4 | hermanus
# Processing Record 36 of Set 4 | mollerussa
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | 'ohonua
# Processing Record 39 of Set 4 | prado
# Processing Record 40 of Set 4 | katsuren-haebaru
# Processing Record 41 of Set 4 | midvagur
# Processing Record 42 of Set 4 | ventura
# Processing Record 43 of Set 4 | cantaura
# Processing Record 44 of Set 4 | pangoa
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | saipan
# Processing Record 47 of Set 4 | stanley
# Processing Record 48 of Set 4 | kattivakkam
# Processing Record 49 of Set 4 | ghadamis
# Processing Record 0 of Set 5 | murzuq
# Processing Record 1 of Set 5 | ankazoabo
# Processing Record 2 of Set 5 | jayapura
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | suva
# Processing Record 5 of Set 5 | manismata
# Processing Record 6 of Set 5 | mesudiye
# Processing Record 7 of Set 5 | sirte
# Processing Record 8 of Set 5 | awjilah
# Processing Record 9 of Set 5 | port mathurin
# Processing Record 10 of Set 5 | merizo village
# Processing Record 11 of Set 5 | kawthoung
# Processing Record 12 of Set 5 | dunedin
# Processing Record 13 of Set 5 | lugovoye
# Processing Record 14 of Set 5 | luau
# Processing Record 15 of Set 5 | canutama
# Processing Record 16 of Set 5 | mili
# Processing Record 17 of Set 5 | tutoia
# Processing Record 18 of Set 5 | stony plain
# Processing Record 19 of Set 5 | naha
# Processing Record 20 of Set 5 | khash
# Processing Record 21 of Set 5 | sierra grande
# Processing Record 22 of Set 5 | fort bragg
# Processing Record 23 of Set 5 | mount pearl
# Processing Record 24 of Set 5 | praia da vitoria
# Processing Record 25 of Set 5 | greymouth
# Processing Record 26 of Set 5 | fale old settlement
# Processing Record 27 of Set 5 | dwarka
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | goz beida
# Processing Record 30 of Set 5 | saint-denis
# Processing Record 31 of Set 5 | masterton
# Processing Record 32 of Set 5 | fuvahmulah
# Processing Record 33 of Set 5 | daru
# Processing Record 34 of Set 5 | antsiranana
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | popayan
# Processing Record 37 of Set 5 | san patricio
# Processing Record 38 of Set 5 | george town
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | dudinka
# Processing Record 42 of Set 5 | dakoro
# Processing Record 43 of Set 5 | waddan
# Processing Record 44 of Set 5 | tazacorte
# Processing Record 45 of Set 5 | zaranj
# Processing Record 46 of Set 5 | mendi
# Processing Record 47 of Set 5 | nadym
# Processing Record 48 of Set 5 | bel ombre
# Processing Record 49 of Set 5 | zhangjiajie
# Processing Record 0 of Set 6 | sisimiut
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | tuy hoa
# Processing Record 3 of Set 6 | paka
# Processing Record 4 of Set 6 | langzhong
# Processing Record 5 of Set 6 | boguchar
# Processing Record 6 of Set 6 | cooma
# Processing Record 7 of Set 6 | taoudenni
# Processing Record 8 of Set 6 | akrehamn
# Processing Record 9 of Set 6 | gorom-gorom
# Processing Record 10 of Set 6 | valle de la pascua
# Processing Record 11 of Set 6 | cole harbour
# Processing Record 12 of Set 6 | pertek
# Processing Record 13 of Set 6 | revelstoke
# Processing Record 14 of Set 6 | guane
# Processing Record 15 of Set 6 | ahau
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | batang
# Processing Record 18 of Set 6 | korsun-shevchenkivskyi
# Processing Record 19 of Set 6 | caico
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | elko
# Processing Record 22 of Set 6 | xanthi
# Processing Record 23 of Set 6 | san nicolas
# Processing Record 24 of Set 6 | mugia
# Processing Record 25 of Set 6 | miracema do tocantins
# Processing Record 26 of Set 6 | waingapu
# Processing Record 27 of Set 6 | ceerigaabo
# Processing Record 28 of Set 6 | toga village
# Processing Record 29 of Set 6 | luanda
# Processing Record 30 of Set 6 | sarina
# Processing Record 31 of Set 6 | tozeur
# Processing Record 32 of Set 6 | avarua
# Processing Record 33 of Set 6 | manohar thana
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | new norfolk
# Processing Record 36 of Set 6 | nadi
# Processing Record 37 of Set 6 | alice springs
# Processing Record 38 of Set 6 | mbanza kongo
# Processing Record 39 of Set 6 | mandiana
# Processing Record 40 of Set 6 | mana
# Processing Record 41 of Set 6 | och'amch'ire
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | victoria
# Processing Record 44 of Set 6 | prince rupert
# Processing Record 45 of Set 6 | dakhla
# Processing Record 46 of Set 6 | east london
# Processing Record 47 of Set 6 | kununurra
# Processing Record 48 of Set 6 | tralee
# Processing Record 49 of Set 6 | bonthe
# Processing Record 0 of Set 7 | ust-nera
# Processing Record 1 of Set 7 | malone
# Processing Record 2 of Set 7 | st. john's
# Processing Record 3 of Set 7 | pemangkat
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | auki
# Processing Record 6 of Set 7 | chadan
# Processing Record 7 of Set 7 | trinidad
# Processing Record 8 of Set 7 | port alfred
# Processing Record 9 of Set 7 | sakaiminato
# Processing Record 10 of Set 7 | vorkuta
# Processing Record 11 of Set 7 | calingasta
# Processing Record 12 of Set 7 | ebon
# Processing Record 13 of Set 7 | kisangani
# Processing Record 14 of Set 7 | kayes
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | le port
# Processing Record 17 of Set 7 | acapulco de juarez
# Processing Record 18 of Set 7 | vorgashor
# Processing Record 19 of Set 7 | la paz
# Processing Record 20 of Set 7 | mbengwi
# Processing Record 21 of Set 7 | caister-on-sea
# Processing Record 22 of Set 7 | bathsheba
# Processing Record 23 of Set 7 | igarka
# Processing Record 24 of Set 7 | la'ie
# Processing Record 25 of Set 7 | zhangjiakou
# Processing Record 26 of Set 7 | hauterive
# Processing Record 27 of Set 7 | aquidauana
# Processing Record 28 of Set 7 | crane
# Processing Record 29 of Set 7 | galesong
# Processing Record 30 of Set 7 | kuusamo
# Processing Record 31 of Set 7 | we
# Processing Record 32 of Set 7 | tahe
# Processing Record 33 of Set 7 | alotau
# Processing Record 34 of Set 7 | chui
# Processing Record 35 of Set 7 | aasiaat
# Processing Record 36 of Set 7 | smithers
# Processing Record 37 of Set 7 | klaksvik
# Processing Record 38 of Set 7 | vingt cinq
# Processing Record 39 of Set 7 | kapuskasing
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | eenhana
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | tobi village
# Processing Record 44 of Set 7 | puerto baquerizo moreno
# Processing Record 45 of Set 7 | baikunthpur
# Processing Record 46 of Set 7 | remire-montjoly
# Processing Record 47 of Set 7 | berlin
# Processing Record 48 of Set 7 | slave lake
# Processing Record 49 of Set 7 | pokhara
# Processing Record 0 of Set 8 | la mira
# Processing Record 1 of Set 8 | salym
# Processing Record 2 of Set 8 | saint-philippe
# Processing Record 3 of Set 8 | cidreira
# Processing Record 4 of Set 8 | eirunepe
# Processing Record 5 of Set 8 | mudanjiang
# Processing Record 6 of Set 8 | gambela
# Processing Record 7 of Set 8 | taro
# Processing Record 8 of Set 8 | shenjiamen
# Processing Record 9 of Set 8 | san pedro pochutla
# Processing Record 10 of Set 8 | queenstown
# Processing Record 11 of Set 8 | coyuca de benitez
# Processing Record 12 of Set 8 | yulinshi
# Processing Record 13 of Set 8 | guatrache
# Processing Record 14 of Set 8 | acarau
# Processing Record 15 of Set 8 | al jawf
# Processing Record 16 of Set 8 | pionerskiy
# Processing Record 17 of Set 8 | tapes
# Processing Record 18 of Set 8 | macedo de cavaleiros
# Processing Record 19 of Set 8 | chibougamau
# Processing Record 20 of Set 8 | kasane
# Processing Record 21 of Set 8 | burang
# Processing Record 22 of Set 8 | kibungo
# Processing Record 23 of Set 8 | howrah
# Processing Record 24 of Set 8 | essaouira
# Processing Record 25 of Set 8 | jiexiu
# Processing Record 26 of Set 8 | mayya
# Processing Record 27 of Set 8 | polyarnyy
# Processing Record 28 of Set 8 | akureyri
# Processing Record 29 of Set 8 | hola prystan'
# Processing Record 30 of Set 8 | boca do acre
# Processing Record 31 of Set 8 | bria
# Processing Record 32 of Set 8 | corpus christi
# Processing Record 33 of Set 8 | sur
# Processing Record 34 of Set 8 | ouricuri
# Processing Record 35 of Set 8 | coquimbo
# Processing Record 36 of Set 8 | lindi
# Processing Record 37 of Set 8 | robertsport
# Processing Record 38 of Set 8 | san juan
# Processing Record 39 of Set 8 | freetown
# Processing Record 40 of Set 8 | kendari
# Processing Record 41 of Set 8 | bolgar
# Processing Record 42 of Set 8 | san antonio del estrecho
# Processing Record 43 of Set 8 | maksi
# Processing Record 44 of Set 8 | singkil
# Processing Record 45 of Set 8 | kil'mez'
# Processing Record 46 of Set 8 | chinnachowk
# Processing Record 47 of Set 8 | milford haven
# Processing Record 48 of Set 8 | rayevskiy
# Processing Record 49 of Set 8 | handan
# Processing Record 0 of Set 9 | ghat
# Processing Record 1 of Set 9 | renk
# Processing Record 2 of Set 9 | carauari
# Processing Record 3 of Set 9 | shingu
# Processing Record 4 of Set 9 | san luis
# Processing Record 5 of Set 9 | mont-dore
# Processing Record 6 of Set 9 | kourou
# Processing Record 7 of Set 9 | mogadishu
# Processing Record 8 of Set 9 | klyuchi
# Processing Record 9 of Set 9 | puerto la cruz
# Processing Record 10 of Set 9 | sao miguel do guama
# Processing Record 11 of Set 9 | arar
# Processing Record 12 of Set 9 | bangassou
# Processing Record 13 of Set 9 | suicheng
# Processing Record 14 of Set 9 | devavanya
# Processing Record 15 of Set 9 | argostolion
# Processing Record 16 of Set 9 | hasaki
# Processing Record 17 of Set 9 | sabang
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | xining
# Processing Record 20 of Set 9 | tromso
# Processing Record 21 of Set 9 | nago
# Processing Record 22 of Set 9 | ytyk-kyuyel'
# Processing Record 23 of Set 9 | nar'yan-mar
# Processing Record 24 of Set 9 | champerico
# Processing Record 25 of Set 9 | ballito
# Processing Record 26 of Set 9 | aldama
# Processing Record 27 of Set 9 | yaren
# Processing Record 28 of Set 9 | nova sintra
# Processing Record 29 of Set 9 | saynshand
# Processing Record 30 of Set 9 | bojnurd
# Processing Record 31 of Set 9 | coos bay
# Processing Record 32 of Set 9 | meiktila
# Processing Record 33 of Set 9 | kone
# Processing Record 34 of Set 9 | aoulef
# Processing Record 35 of Set 9 | pangody
# Processing Record 36 of Set 9 | ulladulla
# Processing Record 37 of Set 9 | severo-yeniseyskiy
# Processing Record 38 of Set 9 | hassi messaoud
# Processing Record 39 of Set 9 | palmas
# Processing Record 40 of Set 9 | tejen
# Processing Record 41 of Set 9 | ambodifotatra
# Processing Record 42 of Set 9 | hilo
# Processing Record 43 of Set 9 | barclayville
# Processing Record 44 of Set 9 | boa vista
# Processing Record 45 of Set 9 | cedeira
# Processing Record 46 of Set 9 | pisco
# Processing Record 47 of Set 9 | swakopmund
# Processing Record 48 of Set 9 | oamaru
# Processing Record 49 of Set 9 | menaka
# Processing Record 0 of Set 10 | solleftea
# Processing Record 1 of Set 10 | hargeysa
# Processing Record 2 of Set 10 | dogondoutchi
# Processing Record 3 of Set 10 | broken hill
# Processing Record 4 of Set 10 | juneau
# Processing Record 5 of Set 10 | thinadhoo
# Processing Record 6 of Set 10 | nenjiang
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | valozhyn
# Processing Record 9 of Set 10 | pandan
# Processing Record 10 of Set 10 | saint leonards-on-sea
# Processing Record 11 of Set 10 | xilin hot
# Processing Record 12 of Set 10 | euclides da cunha
# Processing Record 13 of Set 10 | la penita de jaltomba
# Processing Record 14 of Set 10 | hillsborough
# Processing Record 15 of Set 10 | kingston
# Processing Record 16 of Set 10 | taltal
# Processing Record 17 of Set 10 | gao
# Processing Record 18 of Set 10 | barcelos
# Processing Record 19 of Set 10 | mabaruma
# Processing Record 20 of Set 10 | mount gambier
# Processing Record 21 of Set 10 | sishilichengzi
# Processing Record 22 of Set 10 | san martin
# Processing Record 23 of Set 10 | bouar
# Processing Record 24 of Set 10 | trinity beach
# Processing Record 25 of Set 10 | yongchuan
# Processing Record 26 of Set 10 | longgang
# Processing Record 27 of Set 10 | lodwar
# Processing Record 28 of Set 10 | balikpapan
# Processing Record 29 of Set 10 | crystal lake
# Processing Record 30 of Set 10 | quellon
# Processing Record 31 of Set 10 | mildura
# Processing Record 32 of Set 10 | maintirano
# Processing Record 33 of Set 10 | yung shue wan
# Processing Record 34 of Set 10 | egilsstadir
# Processing Record 35 of Set 10 | ripley
# Processing Record 36 of Set 10 | sidi khaled
# Processing Record 37 of Set 10 | tyup
# Processing Record 38 of Set 10 | muli
# Processing Record 39 of Set 10 | dingzhou
# Processing Record 40 of Set 10 | kuanda
# Processing Record 41 of Set 10 | jackson
# Processing Record 42 of Set 10 | ialibu
# Processing Record 43 of Set 10 | aykhal
# Processing Record 44 of Set 10 | itoigawa
# Processing Record 45 of Set 10 | alo
# Processing Record 46 of Set 10 | dryden
# Processing Record 47 of Set 10 | laojunmiao
# Processing Record 48 of Set 10 | sretensk
# Processing Record 49 of Set 10 | radviliskis
# Processing Record 0 of Set 11 | brookings
# Processing Record 1 of Set 11 | nuriootpa
# Processing Record 2 of Set 11 | bataipora
# Processing Record 3 of Set 11 | fort saskatchewan
# Processing Record 4 of Set 11 | ingeniero jacobacci
# Processing Record 5 of Set 11 | mariental
# Processing Record 6 of Set 11 | sao joao da barra
# Processing Record 7 of Set 11 | serra talhada
# Processing Record 8 of Set 11 | holualoa
# Processing Record 9 of Set 11 | beardstown
# Processing Record 10 of Set 11 | petrovsk-zabaykal'skiy
# Processing Record 11 of Set 11 | batavia
# Processing Record 12 of Set 11 | nicoya
# Processing Record 13 of Set 11 | salina cruz
# Processing Record 14 of Set 11 | minas de marcona
# Processing Record 15 of Set 11 | patterson
# Processing Record 16 of Set 11 | arkhangel'sk
# Processing Record 17 of Set 11 | wewak
# Processing Record 18 of Set 11 | kembe
# Processing Record 19 of Set 11 | utrik
# Processing Record 20 of Set 11 | bukama
# Processing Record 21 of Set 11 | fisterra
# Processing Record 22 of Set 11 | prince george
# Processing Record 23 of Set 11 | stephenville
# Processing Record 24 of Set 11 | nuuk
# Processing Record 25 of Set 11 | nizhneudinsk
# Processing Record 26 of Set 11 | aracatuba
# Processing Record 27 of Set 11 | barra
# Processing Record 28 of Set 11 | hammerfest
# Processing Record 29 of Set 11 | barabinsk
# Processing Record 30 of Set 11 | floro
# Processing Record 31 of Set 11 | norilsk
# Processing Record 32 of Set 11 | vuktyl
# Processing Record 33 of Set 11 | linqiong
# Processing Record 34 of Set 11 | kostomuksha
# Processing Record 35 of Set 11 | harlingen
# Processing Record 36 of Set 11 | lazaro cardenas
# Processing Record 37 of Set 11 | malango
# Processing Record 38 of Set 11 | oxapampa
# Processing Record 39 of Set 11 | savannah
# Processing Record 40 of Set 11 | kosong
# Processing Record 41 of Set 11 | gaspe
# Processing Record 42 of Set 11 | tofol
# Processing Record 43 of Set 11 | uturoa
# Processing Record 44 of Set 11 | inebolu
# Processing Record 45 of Set 11 | monrovia
# Processing Record 46 of Set 11 | rancho palos verdes
# Processing Record 47 of Set 11 | ilo
# Processing Record 48 of Set 11 | pugachev
# Processing Record 49 of Set 11 | rio branco
# Processing Record 0 of Set 12 | caconda
# Processing Record 1 of Set 12 | mayahi
# Processing Record 2 of Set 12 | raub
# Processing Record 3 of Set 12 | chinde
# Processing Record 4 of Set 12 | porto novo
# Processing Record 5 of Set 12 | palmer
# Processing Record 6 of Set 12 | pavlodar
# Processing Record 7 of Set 12 | yanchep
# Processing Record 8 of Set 12 | nizhniy kuranakh
# Processing Record 9 of Set 12 | tiznit
# Processing Record 10 of Set 12 | flin flon
# Processing Record 11 of Set 12 | baruun-urt
# Processing Record 12 of Set 12 | newman
# Processing Record 13 of Set 12 | nellore
# Processing Record 14 of Set 12 | devinuwara
# Processing Record 15 of Set 12 | pierre
# Processing Record 16 of Set 12 | tranovaho
# Processing Record 17 of Set 12 | hayma'
# Processing Record 18 of Set 12 | zharkent
# Processing Record 19 of Set 12 | ramadi
# Processing Record 20 of Set 12 | kayenta
# Processing Record 21 of Set 12 | seminole
# Processing Record 22 of Set 12 | williston
# Processing Record 23 of Set 12 | gornopravdinsk
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | nagqu
# Processing Record 26 of Set 12 | nabire
# Processing Record 27 of Set 12 | vernon
# Processing Record 28 of Set 12 | cockburn town
# Processing Record 29 of Set 12 | upata
# Processing Record 30 of Set 12 | moissala
# Processing Record 31 of Set 12 | faxinal
# Processing Record 32 of Set 12 | barkhera kalan
# Processing Record 33 of Set 12 | shijiang
# Processing Record 34 of Set 12 | bay harbor
# Processing Record 35 of Set 12 | palikir - national government center
# Processing Record 36 of Set 12 | najera
# Processing Record 37 of Set 12 | nueva gerona
# Processing Record 38 of Set 12 | ulsteinvik
# Processing Record 39 of Set 12 | ondangwa
# Processing Record 40 of Set 12 | ghazni
# Processing Record 41 of Set 12 | kangding
# Processing Record 42 of Set 12 | andkhoy
# Processing Record 43 of Set 12 | bubaque
# Processing Record 44 of Set 12 | smara
# Processing Record 45 of Set 12 | salamanca
# Processing Record 46 of Set 12 | baharly
# Processing Record 47 of Set 12 | muzayri'
# Processing Record 48 of Set 12 | khandyga
# Processing Record 49 of Set 12 | veraval
# Processing Record 0 of Set 13 | kilindoni
# Processing Record 1 of Set 13 | charters towers
# Processing Record 2 of Set 13 | sao vicente
# Processing Record 3 of Set 13 | baie-comeau
# Processing Record 4 of Set 13 | vail
# Processing Record 5 of Set 13 | otaci
# Processing Record 6 of Set 13 | cable beach
# Processing Record 7 of Set 13 | kailua-kona
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | ponta pora
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | anar darah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          612
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  formosa do rio preto -11.0483 -45.1931     70.72      61.0        94.0
# 1    upper grand lagoon  30.1633 -85.7408     80.74      82.0         0.0
# 2           olonkinbyen  70.9221  -8.7187     32.83      91.0        89.0
# 3            isafjordur  66.0755 -23.1240     32.77      74.0        99.0
# 4            verkhov'ye  52.8119  37.2425     56.52      95.0         0.0
#
#    Wind Speed Country          Date
# 0        2.98      BR  1.717465e+09
# 1        5.75      US  1.717465e+09
# 2       27.22      SJ  1.717465e+09
# 3       10.42      IS  1.717465e+09
# 4        7.99      RU  1.717465e+09

# %%
city_data_df.loc[pd.isnull(city_data_df.Lat)]

# %%
city_data_df2 = city_data_df.dropna(how='any').reset_index()
city_data_df2.info()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df2 = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# scatter latitude vs temperature

# Step 1: Get the Data
x = city_data_df2.Lat
y = city_data_df2['Max Temp']

# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(x, y, facecolor="firebrick", edgecolor="black", s=100)

# Step 4: Customizations
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Temperature (F)", fontsize=12, fontstyle="italic")
plt.title("Latitude vs Temperature", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
      
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# scatter latitude vs temperature

# Step 1: Get the Data
x = city_data_df2.Lat
y = city_data_df2.Humidity

# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(x, y, facecolor="firebrick", edgecolor="black", s=100)

# Step 4: Customizations
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Humidity", fontsize=12, fontstyle="italic")
plt.title("Latitude vs Humidity", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
      
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# scatter latitude vs temperature

# Step 1: Get the Data
x = city_data_df2.Lat
y = city_data_df2.Cloudiness

# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(x, y, facecolor="firebrick", edgecolor="black", s=100)

# Step 4: Customizations
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Cloudiness", fontsize=12, fontstyle="italic")
plt.title("Latitude vs Cloudiness", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
      
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter latitude vs temperature

# Step 1: Get the Data
x = city_data_df2.Lat
y = city_data_df2['Wind Speed']

# Step 2: Make the canvas
plt.figure(figsize=(10, 6))

# Step 3: Make the basic plot
plt.scatter(x, y, facecolor="firebrick", edgecolor="black", s=100)

# Step 4: Customizations
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Wind Speed", fontsize=12, fontstyle="italic")
plt.title("Latitude vs Wind Speed", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
      
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_title, y_title, text_coordinates):
    # USING LINREGRESS
   
    
    # makes the line of best fit
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept # calculate the predictions
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # make the plot
    # Step 2: Make the canvas
    plt.figure(figsize=(10, 6))
    
    # Step 3: Make the basic plot
    plt.scatter(x_values, y_values, facecolor="firebrick", edgecolor="black", s=100)
    plt.plot(x_values, regress_values, "r-") # plot the line of best fit
    
    # Step 4: Customizations
    plt.xlabel(x_title, fontsize=12, fontstyle="italic")
    plt.ylabel(y_title, fontsize=12, fontstyle="italic")
    plt.title(f"{x_title} vs {y_title}", fontweight="bold", fontsize=16)
    plt.grid(color="lightgrey", linestyle = "--", alpha=0.5)
    
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df2.loc[(city_data_df2['Lat'] >= 0)]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df2.loc[(city_data_df2['Lat'] < 0)]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Lat', 'Temp', (5,40))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values, 'Lat', 'Temp', (-50,60))

# %% [markdown]
# **Discussion about the linear relationship:** There is a moderate negative relationship between latitude and temperature in northern hemisphere and a strong positive relationship between temperature and latitude in the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df.Humidity
plot_linear_regression(x_values, y_values, 'Lat', 'Humidity', (50,20))

# %%
# Southern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df.Humidity
plot_linear_regression(x_values, y_values, 'Lat', 'Humidity', (50,20))

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak relationship between latitude and humidity in both hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df.Cloudiness
plot_linear_regression(x_values, y_values, 'Lat', 'Cloudiness', (20,60))

# %%
# Southern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df.Cloudiness
plot_linear_regression(x_values, y_values, 'Lat', 'Cloudiness', (20,60))

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak relationship between Cloudiness and Latitude in both hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Lat', 'Wind Speed', (20,25))

# %%
# Southern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Lat', 'Wind Speed', (20,25))

# %% [markdown]
# **Discussion about the linear relationship:** There is a nearly 0 (weak) relationship between wind speed and latitude in both hemispheres.
